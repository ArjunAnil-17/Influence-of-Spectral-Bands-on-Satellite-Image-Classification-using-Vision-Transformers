# %%
# !wget https://madm.dfki.de/files/sentinel/EuroSATallBands.zip
# !unzip "/content/EuroSATallBands.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2294.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1854.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1426.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1381.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_647.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_581.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_226.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2819.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_922.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_550.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1208.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_131.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_696.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1669.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_63.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1357.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1882.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2242.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2997.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1736.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1091.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2623.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2184.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_718.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2155.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1040.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2293.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2946.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2534.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_379.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1386.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1421.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1853.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1118.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_640.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1579.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_221.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_586.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_557.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_925.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_691.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_136.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_64.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_801.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_473.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2599.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_4.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_764.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2129.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2548.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_305.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2071.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1164.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2410.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2862.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_988.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1977.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1505.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1273.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_959.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2366.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_18.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1612.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2707.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2973.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2501.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_899.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1414.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1866.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2160.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1075.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1703.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2616.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1362.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_848.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2277.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_103.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_51.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_562.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_910.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2488.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2459.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_214.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_80.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_675.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2038.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1468.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_330.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_497.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1009.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_751.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_780.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_834.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_446.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1627.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1180.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2732.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2095.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1246.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1993.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2353.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2886.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2382.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2425.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2857.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_268.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1297.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1942.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1530.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_609.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2044.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1151.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_490.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_337.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2908.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_756.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_787.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1778.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_441.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_833.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1319.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1187.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1620.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_178.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2092.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2735.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1994.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1241.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2881.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2354.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_519.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2850.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2422.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2385.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1537.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1945.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1290.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2043.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1156.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2506.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2974.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1861.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1413.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2167.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1072.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1704.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2611.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1365.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2270.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_104.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2749.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_56.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2328.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_917.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_565.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1939.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_213.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_87.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2798.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_672.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2574.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2906.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_339.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1813.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1461.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_758.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2115.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1000.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1776.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2663.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_789.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1317.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2202.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_176.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_24.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1189.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_965.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_517.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1539.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_261.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1158.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_600.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2508.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_345.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_890.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_724.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2169.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_394.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_433.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_841.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_58.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1652.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2747.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1233.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1594.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_919.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2326.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2481.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2822.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2450.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1545.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1937.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2796.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2031.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1683.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1124.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_89.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1868.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_897.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_342.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_723.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2618.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2279.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_846.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_434.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_393.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1655.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2740.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1593.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1234.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2486.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2321.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2457.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2825.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1930.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1542.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2036.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2791.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1123.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1684.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_499.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2901.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2573.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1466.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1814.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2112.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1007.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1771.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2664.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1310.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2205.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_448.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_171.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1629.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_23.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2888.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_510.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_962.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1248.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1299.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_266.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2859.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_607.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1211.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2304.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_549.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1670.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_128.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2765.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2013.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1106.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_598.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2800.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2472.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1567.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1915.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_706.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1398.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_367.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2958.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2989.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_411.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_863.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1349.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1728.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2378.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_947.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_535.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_292.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_154.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2719.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_185.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_622.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1969.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_996.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_243.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2137.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2690.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1022.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1785.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2556.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2924.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1831.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1443.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1492.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1335.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2587.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2220.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1754.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2641.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_295.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_532.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_940.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_153.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_625.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_182.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2068.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2409.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_244.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_991.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2697.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2130.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1782.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1025.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2923.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2551.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1444.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1836.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1332.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1495.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_818.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2227.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2580.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1753.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2646.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1216.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2303.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1677.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2762.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_688.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_659.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2014.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1101.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2475.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2807.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_238.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1912.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1560.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1059.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_701.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1438.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_360.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_864.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_416.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1088.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1264.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2371.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1605.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2710.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2066.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1173.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2407.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2875.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1960.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1512.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2699.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_773.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1838.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_312.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2229.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_816.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_464.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2648.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_540.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_932.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1218.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_121.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_686.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1679.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_73.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_657.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_591.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_236.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2809.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2142.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1057.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2951.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2523.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2284.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1436.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1844.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1391.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1895.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1340.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2980.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2255.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_418.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1086.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1721.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2193.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2634.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_935.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_547.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_681.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_126.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_74.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1108.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_650.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1569.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_231.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_596.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_708.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2145.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1050.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2283.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2524.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2956.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_369.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1396.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1843.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1431.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1347.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1892.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2252.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2987.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1726.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1081.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2633.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2194.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1263.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_949.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2376.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1602.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2717.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2061.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1174.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2872.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2400.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_998.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1515.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1967.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_774.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2139.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2558.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_315.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_463.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_811.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2589.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2449.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_204.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_90.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_665.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2028.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_113.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_41.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_900.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_572.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2498.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1713.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2606.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1372.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_858.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2267.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2511.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2963.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_889.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1876.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1404.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2170.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1065.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2392.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2847.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2435.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_278.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1287.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1520.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1952.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_619.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2054.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1141.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1637.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1190.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2722.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2085.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1256.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1983.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2343.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2896.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_790.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_456.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_824.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1478.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_320.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_487.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1019.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_741.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2432.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2840.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2395.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1955.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1527.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1280.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2053.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1146.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1197.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1630.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_168.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2082.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2725.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1984.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1251.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2891.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2344.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_509.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_797.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1768.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_823.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_451.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_1309.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_480.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_327.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_2918.tif
# ...
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1682.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1125.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_983.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_256.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2030.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1936.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1544.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2451.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_190.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_637.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1001.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_372.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2114.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1460.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1812.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_713.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2203.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1316.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_876.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_404.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1777.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1188.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1159.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1538.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1099.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_43.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_92.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1429.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1048.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1903.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1571.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2464.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_602.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1110.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_263.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2005.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_515.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_967.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1666.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_174.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2312.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1207.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_843.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_431.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_396.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1742.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2236.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1323.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1484.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1455.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1827.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_726.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1793.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1034.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_892.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_347.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2121.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2418.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2079.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_569.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_108.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_7.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_391.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_436.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_844.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1745.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_38.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2231.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1483.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1324.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1820.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1452.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_721.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1033.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1794.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2126.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_340.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_895.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_679.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1978.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_218.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2369.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1739.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_838.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1358.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_44.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_95.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1389.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1576.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1904.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_605.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2463.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1117.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2002.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_264.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_960.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_512.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1661.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2315.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_173.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1200.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_438.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_36.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2128.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1504.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1976.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2411.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_677.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1165.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_216.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2070.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_912.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_560.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1613.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_101.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2367.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1272.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2185.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_444.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_836.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1737.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1090.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_782.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2243.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1356.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1883.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1387.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1852.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1420.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2292.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_753.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1041.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_495.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_332.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2154.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1578.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1119.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_831.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_443.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2182.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1097.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1730.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2244.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_785.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1884.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1351.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1427.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1855.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1380.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_754.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2295.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1046.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2153.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_335.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_492.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1668.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_969.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1209.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_398.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2238.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_31.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_728.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1829.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_349.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1971.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1503.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_670.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2416.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1162.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2077.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_211.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_567.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_915.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1614.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_2360.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_9.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_106.tif
#   inflating: ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1275.tif

# %% [markdown]
# # Image classification with Vision Transformer
#
# **Author:** [Khalid Salama](https://www.linkedin.com/in/khalid-salama-24403144/)<br>
# **Date created:** 2021/01/18<br>
# **Last modified:** 2021/01/18<br>
# **Description:** Implementing the Vision Transformer (ViT) model for image classification.

# %% [markdown]
# ## Introduction
#
# This example implements the [Vision Transformer (ViT)](https://arxiv.org/abs/2010.11929)
# model by Alexey Dosovitskiy et al. for image classification,
# and demonstrates it on the CIFAR-100 dataset.
# The ViT model applies the Transformer architecture with self-attention to sequences of
# image patches, without using convolution layers.
#
# This example requires TensorFlow 2.4 or higher, as well as
# [TensorFlow Addons](https://www.tensorflow.org/addons/overview),
# which can be installed using the following command:
#
# ```python
# pip install -U tensorflow-addons
# ```

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.3 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
from skimage import io

# %%
#for rgb+nir
import os
from skimage import io
from skimage import img_as_ubyte, img_as_float32
import numpy as np
images_train=[]
labels_train=[]
images_val=[]
labels_val=[]
images_test=[]
labels_test=[]
path="/content/ds/images/remote_sensing/otherDatasets/sentinel_2/tif"
#path="/content/drive/MyDrive/EuroSAT/2750"
for i,j in enumerate(sorted(os.listdir(path))):   
    new_path=os.path.join(path,j)
    for p,k in enumerate(os.listdir(new_path)):
        if p==2000:
            break
        npath = os.path.join(new_path,k)
        image=io.imread(npath)
        im1=image[:,:,1]
        im2=image[:,:,2]
        im3=image[:,:,3]
        im4=image[:,:,7]
        image=np.dstack((im1,im2,im3,im4))
        im=img_as_ubyte(image)
        if p<1400:
            images_train.append(im)
            labels_train.append(i)
                
        elif  p>=1400 and p<1600:
            images_val.append(im)
            labels_val.append(i)            
        else :
            images_test.append(im)
            labels_test.append(i)

# %%
#for multispectral
import os
from skimage import io
from skimage import img_as_ubyte, img_as_float32
import numpy as np
images_train=[]
labels_train=[]
images_val=[]
labels_val=[]
images_test=[]
labels_test=[]
path="/content/drive/Othercomputers/My Laptop/EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif"
for i,j in enumerate(sorted(os.listdir(path))):   
    new_path=os.path.join(path,j)
    for p,k in enumerate(os.listdir(new_path)):
        if p==2000:
            break
        npath = os.path.join(new_path,k)
        image=io.imread(npath)
        im=img_as_ubyte(image)
        if p<1400:
            images_train.append(im)
            labels_train.append(i)
                
        elif  p>=1400 and p<1600:
            images_val.append(im)
            labels_val.append(i)            
        else :
            images_test.append(im)
            labels_test.append(i)

# %%
len(labels_test)
# Out:
# 4000

# %%
import seaborn as sns 
sns.countplot(labels_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
images_train=np.array(images_train)
labels_train=np.array(labels_train)
images_val=np.array(images_val)
labels_val=np.array(labels_val)
images_test=np.array(images_test)
labels_test=np.array(labels_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %% [markdown]
# ## Prepare the data
# ## chnage one parameter at a time and run all the cells below
# ## change patch size to 6,9
# ## change num_heads to 6,7
# ## change transfer_layers to 6,10

# %%
num_classes = 10
input_shape = (64, 64 ,4)
images_train[0].shape
# Out:
# (64, 64, 4)

# %% [markdown]
# ## Configure the hyperparameters
# ## chnage one parameter at a time and run all the cells below
# ## change patch size to 6,9
# ## change num_heads to 6,7
# ## change transformer_layers to 6,10

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 10  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %% [markdown]
# ## Use data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(images_train)

# %% [markdown]
# ## Implement multilayer perceptron (MLP)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Implement patch creation as a layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# ## Implement the patch encoding layer
#
# The `PatchEncoder` layer will linearly transform a patch by projecting it into a
# vector of size `projection_dim`. In addition, it adds a learnable position
# embedding to the projected vector.

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# ## Build the ViT model
#
# The ViT model consists of multiple Transformer blocks,
# which use the `layers.MultiHeadAttention` layer as a self-attention mechanism
# applied to the sequence of patches. The Transformer blocks produce a
# `[batch_size, num_patches, projection_dim]` tensor, which is processed via an
# classifier head with softmax to produce the final class probabilities output.
#
# Unlike the technique described in the [paper](https://arxiv.org/abs/2010.11929),
# which prepends a learnable embedding to the sequence of encoded patches to serve
# as the image representation, all the outputs of the final Transformer block are
# reshaped with `layers.Flatten()` and used as the image
# representation input to the classifier head.
# Note that the `layers.GlobalAveragePooling1D` layer
# could also be used instead to aggregate the outputs of the Transformer block,
# especially when the number of patches and the projection dimensions are large.

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(10)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )


    history = model.fit(
        x=images_train,
        y=labels_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(images_val,labels_val),
        #callbacks=[checkpoint_callback],
    )

    print(model.evaluate(images_test,labels_test))
    return history,model



vit_classifier = create_vit_classifier()
history,model = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 34s 300ms/step - loss: 1.6600 - accuracy: 0.5161 - top-5-accuracy: 0.9068 - val_loss: 0.8629 - val_accuracy: 0.7100 - val_top-5-accuracy: 0.9810
# Epoch 2/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.8908 - accuracy: 0.6956 - top-5-accuracy: 0.9803 - val_loss: 0.6380 - val_accuracy: 0.7790 - val_top-5-accuracy: 0.9930
# Epoch 3/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.6643 - accuracy: 0.7756 - top-5-accuracy: 0.9911 - val_loss: 0.4825 - val_accuracy: 0.8295 - val_top-5-accuracy: 0.9965
# Epoch 4/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.5478 - accuracy: 0.8164 - top-5-accuracy: 0.9943 - val_loss: 0.4405 - val_accuracy: 0.8450 - val_top-5-accuracy: 0.9995
# Epoch 5/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.4996 - accuracy: 0.8338 - top-5-accuracy: 0.9947 - val_loss: 0.3785 - val_accuracy: 0.8780 - val_top-5-accuracy: 0.9960
# Epoch 6/100
# 55/55 [==============================] - 15s 269ms/step - loss: 0.4509 - accuracy: 0.8509 - top-5-accuracy: 0.9959 - val_loss: 0.3736 - val_accuracy: 0.8790 - val_top-5-accuracy: 0.9985
# Epoch 7/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.4306 - accuracy: 0.8604 - top-5-accuracy: 0.9964 - val_loss: 0.3469 - val_accuracy: 0.8810 - val_top-5-accuracy: 0.9995
# Epoch 8/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.3733 - accuracy: 0.8776 - top-5-accuracy: 0.9965 - val_loss: 0.3675 - val_accuracy: 0.8750 - val_top-5-accuracy: 0.9995
# Epoch 9/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.3772 - accuracy: 0.8772 - top-5-accuracy: 0.9971 - val_loss: 0.3411 - val_accuracy: 0.8815 - val_top-5-accuracy: 0.9990
# Epoch 10/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.3559 - accuracy: 0.8817 - top-5-accuracy: 0.9974 - val_loss: 0.3249 - val_accuracy: 0.8945 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.3330 - accuracy: 0.8914 - top-5-accuracy: 0.9978 - val_loss: 0.2876 - val_accuracy: 0.9050 - val_top-5-accuracy: 0.9990
# Epoch 12/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2985 - accuracy: 0.9044 - top-5-accuracy: 0.9985 - val_loss: 0.2818 - val_accuracy: 0.9030 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2942 - accuracy: 0.9002 - top-5-accuracy: 0.9976 - val_loss: 0.2694 - val_accuracy: 0.9140 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2729 - accuracy: 0.9126 - top-5-accuracy: 0.9991 - val_loss: 0.2953 - val_accuracy: 0.9155 - val_top-5-accuracy: 0.9995
# Epoch 15/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2671 - accuracy: 0.9131 - top-5-accuracy: 0.9981 - val_loss: 0.2836 - val_accuracy: 0.9105 - val_top-5-accuracy: 0.9990
# Epoch 16/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2578 - accuracy: 0.9176 - top-5-accuracy: 0.9990 - val_loss: 0.2422 - val_accuracy: 0.9235 - val_top-5-accuracy: 0.9995
# Epoch 17/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2531 - accuracy: 0.9179 - top-5-accuracy: 0.9983 - val_loss: 0.2616 - val_accuracy: 0.9195 - val_top-5-accuracy: 0.9995
# Epoch 18/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2360 - accuracy: 0.9208 - top-5-accuracy: 0.9993 - val_loss: 0.2583 - val_accuracy: 0.9200 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.2212 - accuracy: 0.9286 - top-5-accuracy: 0.9991 - val_loss: 0.2283 - val_accuracy: 0.9305 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2244 - accuracy: 0.9264 - top-5-accuracy: 0.9992 - val_loss: 0.2482 - val_accuracy: 0.9185 - val_top-5-accuracy: 0.9995
# Epoch 21/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2181 - accuracy: 0.9297 - top-5-accuracy: 0.9992 - val_loss: 0.2559 - val_accuracy: 0.9230 - val_top-5-accuracy: 0.9985
# Epoch 22/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.2092 - accuracy: 0.9325 - top-5-accuracy: 0.9994 - val_loss: 0.2498 - val_accuracy: 0.9260 - val_top-5-accuracy: 0.9995
# Epoch 23/100
# 55/55 [==============================] - 15s 269ms/step - loss: 0.2004 - accuracy: 0.9325 - top-5-accuracy: 0.9992 - val_loss: 0.2232 - val_accuracy: 0.9240 - val_top-5-accuracy: 0.9985
# Epoch 24/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1994 - accuracy: 0.9319 - top-5-accuracy: 0.9994 - val_loss: 0.2494 - val_accuracy: 0.9225 - val_top-5-accuracy: 0.9990
# Epoch 25/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1979 - accuracy: 0.9360 - top-5-accuracy: 0.9994 - val_loss: 0.2423 - val_accuracy: 0.9265 - val_top-5-accuracy: 0.9995
# Epoch 26/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1797 - accuracy: 0.9414 - top-5-accuracy: 0.9997 - val_loss: 0.2284 - val_accuracy: 0.9315 - val_top-5-accuracy: 0.9995
# Epoch 27/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1762 - accuracy: 0.9411 - top-5-accuracy: 0.9996 - val_loss: 0.2220 - val_accuracy: 0.9275 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1938 - accuracy: 0.9349 - top-5-accuracy: 0.9997 - val_loss: 0.2427 - val_accuracy: 0.9285 - val_top-5-accuracy: 0.9995
# Epoch 29/100
# 55/55 [==============================] - 15s 269ms/step - loss: 0.1786 - accuracy: 0.9416 - top-5-accuracy: 0.9995 - val_loss: 0.2369 - val_accuracy: 0.9325 - val_top-5-accuracy: 0.9995
# Epoch 30/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1678 - accuracy: 0.9457 - top-5-accuracy: 0.9994 - val_loss: 0.2095 - val_accuracy: 0.9380 - val_top-5-accuracy: 0.9990
# Epoch 31/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1686 - accuracy: 0.9426 - top-5-accuracy: 0.9995 - val_loss: 0.2618 - val_accuracy: 0.9355 - val_top-5-accuracy: 0.9985
# Epoch 32/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1704 - accuracy: 0.9440 - top-5-accuracy: 0.9994 - val_loss: 0.2310 - val_accuracy: 0.9275 - val_top-5-accuracy: 0.9990
# Epoch 33/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1731 - accuracy: 0.9422 - top-5-accuracy: 0.9994 - val_loss: 0.2373 - val_accuracy: 0.9295 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1562 - accuracy: 0.9504 - top-5-accuracy: 0.9998 - val_loss: 0.2738 - val_accuracy: 0.9260 - val_top-5-accuracy: 0.9995
# Epoch 35/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1728 - accuracy: 0.9454 - top-5-accuracy: 0.9996 - val_loss: 0.2320 - val_accuracy: 0.9320 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1614 - accuracy: 0.9472 - top-5-accuracy: 0.9993 - val_loss: 0.2255 - val_accuracy: 0.9320 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1478 - accuracy: 0.9497 - top-5-accuracy: 0.9997 - val_loss: 0.2164 - val_accuracy: 0.9400 - val_top-5-accuracy: 0.9995
# Epoch 38/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1527 - accuracy: 0.9496 - top-5-accuracy: 0.9995 - val_loss: 0.2077 - val_accuracy: 0.9340 - val_top-5-accuracy: 0.9995
# Epoch 39/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1437 - accuracy: 0.9539 - top-5-accuracy: 0.9996 - val_loss: 0.2158 - val_accuracy: 0.9390 - val_top-5-accuracy: 0.9995
# Epoch 40/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1464 - accuracy: 0.9516 - top-5-accuracy: 0.9995 - val_loss: 0.1925 - val_accuracy: 0.9410 - val_top-5-accuracy: 0.9995
# Epoch 41/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1434 - accuracy: 0.9530 - top-5-accuracy: 0.9999 - val_loss: 0.2369 - val_accuracy: 0.9345 - val_top-5-accuracy: 0.9990
# Epoch 42/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1403 - accuracy: 0.9531 - top-5-accuracy: 0.9998 - val_loss: 0.2532 - val_accuracy: 0.9285 - val_top-5-accuracy: 0.9990
# Epoch 43/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1301 - accuracy: 0.9561 - top-5-accuracy: 0.9996 - val_loss: 0.2803 - val_accuracy: 0.9395 - val_top-5-accuracy: 0.9990
# Epoch 44/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1257 - accuracy: 0.9585 - top-5-accuracy: 0.9999 - val_loss: 0.2336 - val_accuracy: 0.9345 - val_top-5-accuracy: 0.9990
# Epoch 45/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1291 - accuracy: 0.9556 - top-5-accuracy: 0.9997 - val_loss: 0.2847 - val_accuracy: 0.9305 - val_top-5-accuracy: 0.9985
# Epoch 46/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1493 - accuracy: 0.9516 - top-5-accuracy: 0.9995 - val_loss: 0.2279 - val_accuracy: 0.9445 - val_top-5-accuracy: 0.9995
# Epoch 47/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1318 - accuracy: 0.9590 - top-5-accuracy: 0.9996 - val_loss: 0.2246 - val_accuracy: 0.9390 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1413 - accuracy: 0.9531 - top-5-accuracy: 0.9994 - val_loss: 0.2103 - val_accuracy: 0.9435 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1204 - accuracy: 0.9618 - top-5-accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9410 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1163 - accuracy: 0.9617 - top-5-accuracy: 0.9998 - val_loss: 0.2592 - val_accuracy: 0.9315 - val_top-5-accuracy: 0.9985
# Epoch 51/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1215 - accuracy: 0.9596 - top-5-accuracy: 0.9996 - val_loss: 0.2243 - val_accuracy: 0.9440 - val_top-5-accuracy: 0.9995
# Epoch 52/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1114 - accuracy: 0.9627 - top-5-accuracy: 0.9999 - val_loss: 0.2550 - val_accuracy: 0.9305 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1251 - accuracy: 0.9563 - top-5-accuracy: 0.9999 - val_loss: 0.2560 - val_accuracy: 0.9285 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1288 - accuracy: 0.9589 - top-5-accuracy: 0.9997 - val_loss: 0.2331 - val_accuracy: 0.9385 - val_top-5-accuracy: 0.9990
# Epoch 55/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1226 - accuracy: 0.9587 - top-5-accuracy: 0.9997 - val_loss: 0.2167 - val_accuracy: 0.9435 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1120 - accuracy: 0.9620 - top-5-accuracy: 0.9998 - val_loss: 0.2358 - val_accuracy: 0.9425 - val_top-5-accuracy: 0.9995
# Epoch 57/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1061 - accuracy: 0.9643 - top-5-accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9365 - val_top-5-accuracy: 0.9990
# Epoch 58/100
# 55/55 [==============================] - 15s 266ms/step - loss: 0.1030 - accuracy: 0.9667 - top-5-accuracy: 0.9998 - val_loss: 0.2374 - val_accuracy: 0.9430 - val_top-5-accuracy: 0.9985
# Epoch 59/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1215 - accuracy: 0.9601 - top-5-accuracy: 0.9997 - val_loss: 0.2570 - val_accuracy: 0.9290 - val_top-5-accuracy: 0.9990
# Epoch 60/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1095 - accuracy: 0.9638 - top-5-accuracy: 0.9999 - val_loss: 0.2503 - val_accuracy: 0.9395 - val_top-5-accuracy: 0.9995
# Epoch 61/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1058 - accuracy: 0.9653 - top-5-accuracy: 0.9999 - val_loss: 0.2466 - val_accuracy: 0.9405 - val_top-5-accuracy: 0.9990
# Epoch 62/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0994 - accuracy: 0.9669 - top-5-accuracy: 1.0000 - val_loss: 0.2472 - val_accuracy: 0.9375 - val_top-5-accuracy: 0.9990
# Epoch 63/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1205 - accuracy: 0.9600 - top-5-accuracy: 0.9996 - val_loss: 0.2340 - val_accuracy: 0.9410 - val_top-5-accuracy: 0.9995
# Epoch 64/100
# 55/55 [==============================] - 15s 269ms/step - loss: 0.1188 - accuracy: 0.9624 - top-5-accuracy: 0.9995 - val_loss: 0.2725 - val_accuracy: 0.9320 - val_top-5-accuracy: 0.9975
# Epoch 65/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1130 - accuracy: 0.9642 - top-5-accuracy: 0.9996 - val_loss: 0.2290 - val_accuracy: 0.9340 - val_top-5-accuracy: 0.9980
# Epoch 66/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0990 - accuracy: 0.9658 - top-5-accuracy: 0.9999 - val_loss: 0.2423 - val_accuracy: 0.9400 - val_top-5-accuracy: 0.9980
# Epoch 67/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1006 - accuracy: 0.9665 - top-5-accuracy: 0.9999 - val_loss: 0.2230 - val_accuracy: 0.9485 - val_top-5-accuracy: 0.9990
# Epoch 68/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0945 - accuracy: 0.9678 - top-5-accuracy: 0.9999 - val_loss: 0.2576 - val_accuracy: 0.9360 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0948 - accuracy: 0.9676 - top-5-accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9455 - val_top-5-accuracy: 0.9995
# Epoch 70/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0954 - accuracy: 0.9698 - top-5-accuracy: 0.9999 - val_loss: 0.2448 - val_accuracy: 0.9425 - val_top-5-accuracy: 0.9985
# Epoch 71/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0872 - accuracy: 0.9714 - top-5-accuracy: 0.9999 - val_loss: 0.2512 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9990
# Epoch 72/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0989 - accuracy: 0.9676 - top-5-accuracy: 0.9999 - val_loss: 0.2467 - val_accuracy: 0.9385 - val_top-5-accuracy: 0.9990
# Epoch 73/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.1021 - accuracy: 0.9671 - top-5-accuracy: 0.9999 - val_loss: 0.2425 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9985
# Epoch 74/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0883 - accuracy: 0.9713 - top-5-accuracy: 0.9999 - val_loss: 0.2270 - val_accuracy: 0.9485 - val_top-5-accuracy: 0.9995
# Epoch 75/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0818 - accuracy: 0.9737 - top-5-accuracy: 0.9999 - val_loss: 0.2444 - val_accuracy: 0.9425 - val_top-5-accuracy: 0.9990
# Epoch 76/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.1021 - accuracy: 0.9667 - top-5-accuracy: 0.9999 - val_loss: 0.2731 - val_accuracy: 0.9325 - val_top-5-accuracy: 0.9990
# Epoch 77/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0976 - accuracy: 0.9686 - top-5-accuracy: 1.0000 - val_loss: 0.2790 - val_accuracy: 0.9280 - val_top-5-accuracy: 0.9990
# Epoch 78/100
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0972 - accuracy: 0.9690 - top-5-accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9360 - val_top-5-accuracy: 0.9985
# Epoch 79/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0839 - accuracy: 0.9722 - top-5-accuracy: 0.9997 - val_loss: 0.2505 - val_accuracy: 0.9390 - val_top-5-accuracy: 0.9990
# Epoch 80/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0919 - accuracy: 0.9692 - top-5-accuracy: 0.9998 - val_loss: 0.2494 - val_accuracy: 0.9455 - val_top-5-accuracy: 0.9995
# Epoch 81/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0823 - accuracy: 0.9728 - top-5-accuracy: 0.9999 - val_loss: 0.2315 - val_accuracy: 0.9475 - val_top-5-accuracy: 0.9990
# Epoch 82/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0804 - accuracy: 0.9730 - top-5-accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9455 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0919 - accuracy: 0.9714 - top-5-accuracy: 0.9999 - val_loss: 0.2196 - val_accuracy: 0.9460 - val_top-5-accuracy: 0.9990
# Epoch 84/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0933 - accuracy: 0.9689 - top-5-accuracy: 0.9999 - val_loss: 0.2565 - val_accuracy: 0.9410 - val_top-5-accuracy: 0.9985
# Epoch 85/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0840 - accuracy: 0.9728 - top-5-accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9445 - val_top-5-accuracy: 0.9985
# Epoch 86/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0789 - accuracy: 0.9736 - top-5-accuracy: 0.9999 - val_loss: 0.2544 - val_accuracy: 0.9380 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0863 - accuracy: 0.9711 - top-5-accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9475 - val_top-5-accuracy: 0.9995
# Epoch 88/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0800 - accuracy: 0.9739 - top-5-accuracy: 1.0000 - val_loss: 0.2375 - val_accuracy: 0.9455 - val_top-5-accuracy: 0.9995
# Epoch 89/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0801 - accuracy: 0.9733 - top-5-accuracy: 0.9999 - val_loss: 0.2379 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9995
# Epoch 90/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0847 - accuracy: 0.9736 - top-5-accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9475 - val_top-5-accuracy: 0.9995
# Epoch 91/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0644 - accuracy: 0.9780 - top-5-accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.9420 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0801 - accuracy: 0.9751 - top-5-accuracy: 0.9999 - val_loss: 0.2434 - val_accuracy: 0.9410 - val_top-5-accuracy: 0.9990
# Epoch 93/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0825 - accuracy: 0.9726 - top-5-accuracy: 0.9999 - val_loss: 0.2326 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9995
# Epoch 94/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0726 - accuracy: 0.9749 - top-5-accuracy: 0.9999 - val_loss: 0.2914 - val_accuracy: 0.9345 - val_top-5-accuracy: 0.9985
# Epoch 95/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0718 - accuracy: 0.9761 - top-5-accuracy: 0.9999 - val_loss: 0.3373 - val_accuracy: 0.9265 - val_top-5-accuracy: 0.9980
# Epoch 96/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0762 - accuracy: 0.9736 - top-5-accuracy: 0.9999 - val_loss: 0.2434 - val_accuracy: 0.9530 - val_top-5-accuracy: 0.9990
# Epoch 97/100
# 55/55 [==============================] - 15s 267ms/step - loss: 0.0764 - accuracy: 0.9752 - top-5-accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9530 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0663 - accuracy: 0.9793 - top-5-accuracy: 0.9999 - val_loss: 0.2328 - val_accuracy: 0.9435 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0746 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.2547 - val_accuracy: 0.9420 - val_top-5-accuracy: 0.9980
# Epoch 100/100
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0701 - accuracy: 0.9773 - top-5-accuracy: 1.0000 - val_loss: 0.2404 - val_accuracy: 0.9410 - val_top-5-accuracy: 0.9990
# 125/125 [==============================] - 4s 22ms/step - loss: 0.2702 - accuracy: 0.9402 - top-5-accuracy: 0.9992
# [0.27023476362228394, 0.9402499794960022, 0.9992499947547913]

# %%
model.evaluate(images_test,labels_test)
# Out:
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2702 - accuracy: 0.9402 - top-5-accuracy: 0.9992
# [0.27023476362228394, 0.9402499794960022, 0.9992499947547913]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'],label="train accuracy")
plt.plot(history.history['val_accuracy'],label="validation accuracy")
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc="down right")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'down right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
plt.plot(history.history['loss'],label="train loss")
plt.plot(history.history['val_loss'],label="validation loss")
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc="down right")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Unrecognized location 'down right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# After 100 epochs, the ViT model achieves around 55% accuracy and
# 82% top-5 accuracy on the test data. These are not competitive results on the CIFAR-100 dataset,
# as a ResNet50V2 trained from scratch on the same data can achieve 67% accuracy.
#
# Note that the state of the art results reported in the
# [paper](https://arxiv.org/abs/2010.11929) are achieved by pre-training the ViT model using
# the JFT-300M dataset, then fine-tuning it on the target dataset. To improve the model quality
# without pre-training, you can try to train the model for more epochs, use a larger number of
# Transformer layers, resize the input images, change the patch size, or increase the projection dimensions.
# Besides, as mentioned in the paper, the quality of the model is affected not only by architecture choices,
# but also by parameters such as the learning rate schedule, optimizer, weight decay, etc.
# In practice, it's recommended to fine-tune a ViT model
# that was pre-trained using a large, high-resolution dataset.

# %%
predictions=model.predict(images_test).argmax(axis=1)

# %%
print(classification_report(labels_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       400
#            1       0.98      0.99      0.99       400
#            2       0.98      0.96      0.97       400
#            3       0.93      0.90      0.92       400
#            4       0.95      0.98      0.96       400
#            5       0.96      0.96      0.96       400
#            6       0.97      0.94      0.96       400
#            7       0.95      0.97      0.96       400
#            8       0.98      0.98      0.98       400
#            9       1.00      1.00      1.00       400
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000

# %%
import matplotlib.pyplot as plt
#for rgb
def show_values(pc, fmt="%.2f", **kw):

    pc.update_scalarmappable()
    ax = pc.axes
    #ax = pc.axes# FOR LATEST MATPLOTLIB
    #Use zip BELOW IN PYTHON 3
    for p, color, value in zip(pc.get_paths(), pc.get_facecolors(), pc.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.all(color[:3] > 0.5):
            color = (0.0, 0.0, 0.0)
        else:
            color = (1.0, 1.0, 1.0)
        ax.text(x, y, fmt % value, ha="center", va="center", color=color, **kw)


def cm2inch(*tupl):

    inch = 2.54
    if type(tupl[0]) == tuple:
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)


def heatmap(AUC, title, xlabel, ylabel, xticklabels, yticklabels, figure_width=40, figure_height=20, correct_orientation=False, cmap='RdBu'):
    # Plot it out
    fig, ax = plt.subplots()    
    #c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap='RdBu', vmin=0.0, vmax=1.0)
    c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap=cmap)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(AUC.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(AUC.shape[1]) + 0.5, minor=False)

    # set tick labels
    #ax.set_xticklabels(np.arange(1,AUC.shape[1]+1), minor=False)
    ax.set_xticklabels(xticklabels, minor=False)
    ax.set_yticklabels(yticklabels, minor=False)

    # set title and x/y labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)      

    # Remove last blank column
    plt.xlim( (0, AUC.shape[1]) )

    # Turn off all the ticks
    ax = plt.gca()    
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False

    # Add color bar
    plt.colorbar(c)

    # Add text in each cell
    show_values(c)

    # Proper orientation (origin at the top left instead of bottom left)
    if correct_orientation:
        ax.invert_yaxis()
        ax.xaxis.tick_top()      

    # resize
    fig = plt.gcf()
    #fig.set_size_inches(cm2inch(40, 20))
    #fig.set_size_inches(cm2inch(40*4, 20*4))
    fig.set_size_inches(cm2inch(figure_width, figure_height))



def plot_classification_report(classification_report, title='Classification report ', cmap='RdBu'):

    lines = classification_report.split('\n')

    classes = []
    plotMat = []
    support = []
    class_names = []

    for line in lines[2 : (len(lines) - 4)]:
        t = line.strip().split()
        if len(t) < 2: continue
        classes.append(t[0])
        v = [float(x) for x in t[1: len(t) - 1]]
        support.append(int(t[-1]))
        class_names.append(t[0])
        print(v)
        plotMat.append(v)

    print('plotMat: {0}'.format(plotMat))
    print('support: {0}'.format(support))

    xlabel = 'Metrics'
    ylabel = 'Classes'
    xticklabels = ['Precision', 'Recall', 'F1-score']
    yticklabels = ['{0} ({1})'.format(class_names[idx], sup) for idx, sup  in enumerate(support)]
    figure_width = 25
    figure_height = len(class_names) + 7
    correct_orientation = False
    heatmap(np.array(plotMat), title, xlabel, ylabel, xticklabels, yticklabels, figure_width, figure_height, correct_orientation, cmap=cmap)


def main():

    sampleClassificationReport = """    precision    recall  f1-score   support

           0       0.97      0.96      0.97       400
           1       0.98      0.99      0.99       400
           2       0.98      0.96      0.97       400
           3       0.93      0.90      0.92       400
           4       0.95      0.98      0.96       400
           5       0.96      0.96      0.96       400
           6       0.97      0.94      0.96       400
           7       0.95      0.97      0.96       400
           8       0.98      0.98      0.98       400
           9       1.00      1.00      1.00       400

    accuracy                           0.97      4000
    macro avg       0.97      0.97      0.97      4000
    weighted avg       0.97      0.97      0.97      4000
    """
    plot_classification_report(sampleClassificationReport)
    plt.show()
    plt.savefig('./test_plot_classif_report.png', dpi=200, format='png', bbox_inches='tight')
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# [0.97, 0.96, 0.97]
# [0.98, 0.99, 0.99]
# [0.98, 0.96, 0.97]
# [0.93, 0.9, 0.92]
# [0.95, 0.98, 0.96]
# [0.96, 0.96, 0.96]
# [0.97, 0.94, 0.96]
# [0.95, 0.97, 0.96]
# [0.98, 0.98, 0.98]
# [1.0, 1.0, 1.0]
# plotMat: [[0.97, 0.96, 0.97], [0.98, 0.99, 0.99], [0.98, 0.96, 0.97], [0.93, 0.9, 0.92], [0.95, 0.98, 0.96], [0.96, 0.96, 0.96], [0.97, 0.94, 0.96], [0.95, 0.97, 0.96], [0.98, 0.98, 0.98], [1.0, 1.0, 1.0]]
# support: [400, 400, 400, 400, 400, 400, 400, 400, 400, 400]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.

# %%
import matplotlib.pyplot as plt
#for rgb
def show_values(pc, fmt="%.2f", **kw):

    pc.update_scalarmappable()
    ax = pc.axes
    #ax = pc.axes# FOR LATEST MATPLOTLIB
    #Use zip BELOW IN PYTHON 3
    for p, color, value in zip(pc.get_paths(), pc.get_facecolors(), pc.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.all(color[:3] > 0.5):
            color = (0.0, 0.0, 0.0)
        else:
            color = (1.0, 1.0, 1.0)
        ax.text(x, y, fmt % value, ha="center", va="center", color=color, **kw)


def cm2inch(*tupl):

    inch = 2.54
    if type(tupl[0]) == tuple:
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)


def heatmap(AUC, title, xlabel, ylabel, xticklabels, yticklabels, figure_width=40, figure_height=20, correct_orientation=False, cmap='RdBu'):
    # Plot it out
    fig, ax = plt.subplots()    
    #c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap='RdBu', vmin=0.0, vmax=1.0)
    c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap=cmap)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(AUC.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(AUC.shape[1]) + 0.5, minor=False)

    # set tick labels
    #ax.set_xticklabels(np.arange(1,AUC.shape[1]+1), minor=False)
    ax.set_xticklabels(xticklabels, minor=False)
    ax.set_yticklabels(yticklabels, minor=False)

    # set title and x/y labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)      

    # Remove last blank column
    plt.xlim( (0, AUC.shape[1]) )

    # Turn off all the ticks
    ax = plt.gca()    
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False

    # Add color bar
    plt.colorbar(c)

    # Add text in each cell
    show_values(c)

    # Proper orientation (origin at the top left instead of bottom left)
    if correct_orientation:
        ax.invert_yaxis()
        ax.xaxis.tick_top()      

    # resize
    fig = plt.gcf()
    #fig.set_size_inches(cm2inch(40, 20))
    #fig.set_size_inches(cm2inch(40*4, 20*4))
    fig.set_size_inches(cm2inch(figure_width, figure_height))



def plot_classification_report(classification_report, title='Classification report ', cmap='RdBu'):

    lines = classification_report.split('\n')

    classes = []
    plotMat = []
    support = []
    class_names = []

    for line in lines[2 : (len(lines) - 4)]:
        t = line.strip().split()
        if len(t) < 2: continue
        classes.append(t[0])
        v = [float(x) for x in t[1: len(t) - 1]]
        support.append(int(t[-1]))
        class_names.append(t[0])
        print(v)
        plotMat.append(v)

    print('plotMat: {0}'.format(plotMat))
    print('support: {0}'.format(support))

    xlabel = 'Metrics'
    ylabel = 'Classes'
    xticklabels = ['Precision', 'Recall', 'F1-score']
    yticklabels = ['{0} ({1})'.format(class_names[idx], sup) for idx, sup  in enumerate(support)]
    figure_width = 25
    figure_height = len(class_names) + 7
    correct_orientation = False
    heatmap(np.array(plotMat), title, xlabel, ylabel, xticklabels, yticklabels, figure_width, figure_height, correct_orientation, cmap=cmap)


def main():

    sampleClassificationReport = """    precision    recall  f1-score   support

           0       0.96      0.84      0.89       400
           1       0.98      0.98      0.98       400
           2       0.90      0.93      0.92       400
           3       0.89      0.89      0.89       400
           4       0.97      0.93      0.95       400
           5       0.89      0.92      0.90       400
           6       0.84      0.92      0.88       400
           7       0.93      0.98      0.96       400
           8       0.91      0.91      0.91       400
           9       0.98      0.96      0.97       400

    accuracy                           0.92      4000
    macro avg       0.93      0.92      0.92      4000
    weighted avg       0.93      0.92      0.92      4000
    """
    plot_classification_report(sampleClassificationReport)
    plt.show()
    plt.savefig('./test_plot_classif_report.png', dpi=200, format='png', bbox_inches='tight')
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# [0.96, 0.84, 0.89]
# [0.98, 0.98, 0.98]
# [0.9, 0.93, 0.92]
# [0.89, 0.89, 0.89]
# [0.97, 0.93, 0.95]
# [0.89, 0.92, 0.9]
# [0.84, 0.92, 0.88]
# [0.93, 0.98, 0.96]
# [0.91, 0.91, 0.91]
# [0.98, 0.96, 0.97]
# plotMat: [[0.96, 0.84, 0.89], [0.98, 0.98, 0.98], [0.9, 0.93, 0.92], [0.89, 0.89, 0.89], [0.97, 0.93, 0.95], [0.89, 0.92, 0.9], [0.84, 0.92, 0.88], [0.93, 0.98, 0.96], [0.91, 0.91, 0.91], [0.98, 0.96, 0.97]]
# support: [400, 400, 400, 400, 400, 400, 400, 400, 400, 400]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.

# %%
#for rgb+ nir
import matplotlib.pyplot as plt
#for rgb
def show_values(pc, fmt="%.2f", **kw):

    pc.update_scalarmappable()
    ax = pc.axes
    #ax = pc.axes# FOR LATEST MATPLOTLIB
    #Use zip BELOW IN PYTHON 3
    for p, color, value in zip(pc.get_paths(), pc.get_facecolors(), pc.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.all(color[:3] > 0.5):
            color = (0.0, 0.0, 0.0)
        else:
            color = (1.0, 1.0, 1.0)
        ax.text(x, y, fmt % value, ha="center", va="center", color=color, **kw)


def cm2inch(*tupl):

    inch = 2.54
    if type(tupl[0]) == tuple:
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)


def heatmap(AUC, title, xlabel, ylabel, xticklabels, yticklabels, figure_width=40, figure_height=20, correct_orientation=False, cmap='RdBu'):
    # Plot it out
    fig, ax = plt.subplots()    
    #c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap='RdBu', vmin=0.0, vmax=1.0)
    c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap=cmap)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(AUC.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(AUC.shape[1]) + 0.5, minor=False)

    # set tick labels
    #ax.set_xticklabels(np.arange(1,AUC.shape[1]+1), minor=False)
    ax.set_xticklabels(xticklabels, minor=False)
    ax.set_yticklabels(yticklabels, minor=False)

    # set title and x/y labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)      

    # Remove last blank column
    plt.xlim( (0, AUC.shape[1]) )

    # Turn off all the ticks
    ax = plt.gca()    
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False

    # Add color bar
    plt.colorbar(c)

    # Add text in each cell
    show_values(c)

    # Proper orientation (origin at the top left instead of bottom left)
    if correct_orientation:
        ax.invert_yaxis()
        ax.xaxis.tick_top()      

    # resize
    fig = plt.gcf()
    #fig.set_size_inches(cm2inch(40, 20))
    #fig.set_size_inches(cm2inch(40*4, 20*4))
    fig.set_size_inches(cm2inch(figure_width, figure_height))



def plot_classification_report(classification_report, title='Classification report ', cmap='RdBu'):

    lines = classification_report.split('\n')

    classes = []
    plotMat = []
    support = []
    class_names = []

    for line in lines[2 : (len(lines) - 4)]:
        t = line.strip().split()
        if len(t) < 2: continue
        classes.append(t[0])
        v = [float(x) for x in t[1: len(t) - 1]]
        support.append(int(t[-1]))
        class_names.append(t[0])
        print(v)
        plotMat.append(v)

    print('plotMat: {0}'.format(plotMat))
    print('support: {0}'.format(support))

    xlabel = 'Metrics'
    ylabel = 'Classes'
    xticklabels = ['Precision', 'Recall', 'F1-score']
    yticklabels = ['{0} ({1})'.format(class_names[idx], sup) for idx, sup  in enumerate(support)]
    figure_width = 25
    figure_height = len(class_names) + 7
    correct_orientation = False
    heatmap(np.array(plotMat), title, xlabel, ylabel, xticklabels, yticklabels, figure_width, figure_height, correct_orientation, cmap=cmap)


def main():

    sampleClassificationReport = """     precision    recall  f1-score   support

           0       0.99      0.83      0.90       400
           1       0.97      0.98      0.97       400
           2       0.93      0.93      0.93       400
           3       0.92      0.89      0.90       400
           4       0.96      0.95      0.96       400
           5       0.92      0.90      0.91       400
           6       0.84      0.91      0.88       400
           7       0.89      0.99      0.94       400
           8       0.98      0.98      0.98       400
           9       0.99      0.99      0.99       400

    accuracy                           0.94      4000
    macro avg       0.94      0.94      0.94      4000
    weighted avg       0.94      0.94      0.94      4000
    """
    plot_classification_report(sampleClassificationReport)
    plt.show()
    plt.savefig('./test_plot_classif_report.png', dpi=200, format='png', bbox_inches='tight')
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# [0.99, 0.83, 0.9]
# [0.97, 0.98, 0.97]
# [0.93, 0.93, 0.93]
# [0.92, 0.89, 0.9]
# [0.96, 0.95, 0.96]
# [0.92, 0.9, 0.91]
# [0.84, 0.91, 0.88]
# [0.89, 0.99, 0.94]
# [0.98, 0.98, 0.98]
# [0.99, 0.99, 0.99]
# plotMat: [[0.99, 0.83, 0.9], [0.97, 0.98, 0.97], [0.93, 0.93, 0.93], [0.92, 0.89, 0.9], [0.96, 0.95, 0.96], [0.92, 0.9, 0.91], [0.84, 0.91, 0.88], [0.89, 0.99, 0.94], [0.98, 0.98, 0.98], [0.99, 0.99, 0.99]]
# support: [400, 400, 400, 400, 400, 400, 400, 400, 400, 400]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
import numpy as np
cm=confusion_matrix(labels_test,predictions)
def plot_confusion_matrix_2(cm,
                      target_names,
                      title='Confusion matrix',
                      cmap=None,
                      normalize=True):
    FONT_SIZE = 8

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8*2, 6*2))    # 8, 6
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=90, fontsize=FONT_SIZE)
        plt.yticks(tick_marks, target_names, fontsize=FONT_SIZE)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     fontsize=FONT_SIZE,
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     fontsize=FONT_SIZE,
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
plot_confusion_matrix_2(cm, sorted(os.listdir("/content/drive/Othercomputers/My Laptop/EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif")), normalize=False, title='Confusion Matrix')
